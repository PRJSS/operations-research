# %% [markdown]
# ### Task 1
# Графическое решение задач линейного программирования

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A=np
B=[1:501]
# Out:
#   File "<ipython-input-24-9ae19376e4a4>", line 1
#     A=[1:501]
#         ^
# SyntaxError: invalid syntax

# %%
plt.plot(A, B)
